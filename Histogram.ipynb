# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('BC_1.xlsx')
data
# Out:
#   Age Group  Total number of Migrant  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0       0-4                        1         NaN         NaN         NaN
# 1       5-9                        2         NaN         NaN         NaN
# 2     10-14                        3         NaN         NaN         NaN
# 3     15-19                        4         NaN         NaN         NaN

# %%
sns.distplot(data['Total number of Migrant'])
# Out:
# <AxesSubplot:xlabel='Total number of Migrant', ylabel='Density'>

# %%
Age_Group = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+']

Total_number_of_Migrant = ['1,89,62,713','2,09,17,565','2,38,76,335','2,92,02,399','4,68,55,749','5,05,67,231','4,64,20,105','4,51,14,917','3,81,61,379','3,31,51,742','2,57,83,138','2,13,54,664','1,97,49,108','1,38,28,278','96,96,149','48,34,573','57,14,991'
]

my_df = pd.DataFrame({'Age Group':pd.Series(Age_Group),
                      'Total number of Migrant':pd.Series(Total_number_of_Migrant)})
my_df
# Out:
#    Age Group Total number of Migrant
# 0        0-4             1,89,62,713
# 1        5-9             2,09,17,565
# 2      10-14             2,38,76,335
# 3      15-19             2,92,02,399
# 4      20-24             4,68,55,749
# 5      25-29             5,05,67,231
# 6      30-34             4,64,20,105
# 7      35-39             4,51,14,917
# 8      40-44             3,81,61,379
# 9      45-49             3,31,51,742
# 10     50-54             2,57,83,138
# 11     55-59             2,13,54,664
# 12     60-64             1,97,49,108
# 13     65-69             1,38,28,278
# 14     70-74               96,96,149
# 15     75-79               48,34,573
# 16       80+               57,14,991

# %%
# plot = sns.histplot(my_df['Age Group'])
# plot = sns.displot(my_df['Total number of Migrant'])
fig, ax = plt.subplots(figsize = (20, 15))
sns.histplot(ax=ax, data=my_df, x="Age Group", y = "Total number of Migrant", color="red")
# plot.set_xlabel('Age Group')
# plot.set_ylabel('Total number of Migrant')
# plot.set_title('Age Groupt vs Total number of Migrant')
plt.show()
# distplot has been deprecated. we can use displot

# %%
sns.jointplot(x = 'Age Group',
              y = 'Total number of Migrant', 
              data = my_df)

# %%
plt.plot(my_df['Age Group'], my_df['Total number of Migrant'])
plt.show()
# plt.xlabel('total_Duration')
# plt.ylabel('krishna_attendance')
