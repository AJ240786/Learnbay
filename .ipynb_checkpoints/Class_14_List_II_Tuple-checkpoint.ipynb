# %%
# List Comprehension
# Netsted List and Method on Lists

# %%
# my_str = 'This is Python class'
# ind = -1
# while True:
#     try:
#         ind = my_str.index('s', ind+1)
#     except:
#         break
#     else:
#         print(ind)
# else:
#     print('Loop execution completed')

i = 0
while i < 5:
    print(i)
    i += 1
else:
    print('Loop execution is completed')
# Out:
# 0
# 1
# 2
# 3
# 4
# Loop execution is completed

# %%
dict([(1, 200), (2, 300)])
# Out:
# {1: 200, 2: 300}

# %%
# List Comprehension - [expr for loop if cond] or [expr for loop]

# Create a list of square of all even numbers between 1 -10
# [i**2 for i in range(1, 11) if i%2 == 0]



if datetime.datetime.fromisoformat(date_time).month()
# Out:
# [4, 16, 36, 64, 100]

# %%
import pandas as pd
import datetime
bike_data = pd.read_csv('datasets/citibike_tripdata.csv', parse_dates = True)
[datetime.datetime.fromisoformat(date_time) for date_time in list(bike_data['starttime']) if datetime.datetime.fromisoformat(date_time).month == 5]

# [datetime.datetime.strptime(date_time, "%Y-%m-%d %H:%M:%S") for date_time in list(bike_data['starttime'])]
# Out:
# [datetime.datetime(2018, 5, 1, 0, 4, 47),
#  datetime.datetime(2018, 5, 1, 1, 31, 10),
#  datetime.datetime(2018, 5, 1, 1, 31, 29),
#  datetime.datetime(2018, 5, 1, 2, 3, 29),
#  datetime.datetime(2018, 5, 1, 4, 27, 12),
#  datetime.datetime(2018, 5, 1, 4, 37, 5),
#  datetime.datetime(2018, 5, 1, 5, 5, 46),
#  datetime.datetime(2018, 5, 1, 5, 11, 50),
#  datetime.datetime(2018, 5, 1, 5, 12, 7),
#  datetime.datetime(2018, 5, 1, 5, 13, 52),
#  datetime.datetime(2018, 5, 1, 5, 18, 36),
#  datetime.datetime(2018, 5, 1, 5, 23, 26),
#  datetime.datetime(2018, 5, 1, 5, 23, 32),
#  datetime.datetime(2018, 5, 1, 5, 31, 40),
#  datetime.datetime(2018, 5, 1, 5, 34, 23),
#  datetime.datetime(2018, 5, 1, 5, 34, 30),
#  datetime.datetime(2018, 5, 1, 5, 41, 11),
#  datetime.datetime(2018, 5, 1, 5, 53, 34),
#  datetime.datetime(2018, 5, 1, 5, 53, 42),
#  datetime.datetime(2018, 5, 1, 5, 53, 43),
#  datetime.datetime(2018, 5, 1, 5, 56, 6),
#  datetime.datetime(2018, 5, 1, 5, 56, 8),
# ...

# %%
print(dir(datetime.datetime))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %%
datetime.datetime.strptime()
# Out:
# Help on built-in function strptime in datetime.datetime:
#
# datetime.datetime.strptime = strptime(...) method of builtins.type instance
#     string, format -> new datetime parsed from a string (like time.strptime()).

# %%
# Netsted List - A list inside a list

# lst = [10,20,30,40,50, [1, 2, 3, 4], 60, 70]
# print(lst[-3][1:3])
# print(lst[5].index(4))

# Create a nested list of shape 2X4
# [[1, 2, 3, 4],
#  [5, 6, 7, 8]]

# out_lst = []
# for row in range(2):
#     in_lst = []
#     for col in range(4):
#         if row == 0:
#             in_lst.append(col+1)
#         if row == 1:
#             in_lst.append(col+5)
#     out_lst.append(in_lst)
# out_lst
 
# out_lst = [[1, 2, 3, 4], [5, 6, 7, 8]]
# row = 1
# in_lst = [5, 6, 7, 8]
# col = 3

[[(col+1 if row == 0 else col+5) for col in range(4)] for row in range(2)]
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
# Method on Lists
# print(dir(list))

# 'copy', 

# append(object) add the object at the end of the list

lst = [10,20,30,40,50]
print(lst)
# lst.append(111)
# print(lst)

# lst.append([1,2, 3, 4])
# print(lst)

# insert(index, value) - it adds the value at the specified index
# lst.insert(3, 444)
# print(lst)

# lst.insert(3, [1, 2, 3,4])
# print(lst)

# extend(sub_lst) - this will add the elements from sub_lst as individual elements in the main list at the end
lst1 = ['Python', True, None, 10.20]
lst.extend(lst1)
print(lst)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50, 'Python', True, None, 10.2]

# %%
#  'pop', 'remove', 'clear', 

# Clear - clears the list and deletes all the elements from list. Leaves empty list behind
# lst1 = ['Python', True, None, 10.20]
# lst1.clear()
# print(lst1)


# pop() - removes the last element from the list
# Returns the removed element from the list as output

# lst1 = ['Python', True, None, 10.20]
# print(lst1.pop())
# print(lst1)

# pop(index) - removes the  element from the list from specified index
# Returns the removed element from the list as output
# lst1 = ['Python', True, None, 10.20]
# print(lst1.pop(2))
# print(lst1)

# If index in not availbel then gives indexError
# print(lst1.pop(30))


# remove(value) - removes the first occurrence of the value from list
# lst1 = [10, 20, 10.20, 20+39j, 'Python', True, None, 10, 20, 'Python', 100,'Python']
# lst1.remove('Python')
# print(lst1)

# %%
# 'count', 'index',

lst1 = [10, 20, 10.20, 20+39j, 'Python', True, None, 10, 20, 'Python', 100,'Python']
# print(lst1.count('Python'))
# print(lst1.count(10))


# lst1.index('Python')

print(len(lst1))
# Out:
# 12

# %%
#  'reverse', 'sort'

# lst1 = [10, 20, 10.20, 20+39j, 'Python', True, None, 10, 20, 'Python', 100,'Python']
# lst1.reverse()
# print(lst1)


# sort() - sorts the list in ascending order
# Note all the element inside the list should be of same type
# sort method internally uses comparison operator
# lst1.sort()


# lst2 = [10,90, 9, 1, 0, 99, 8, 78, 76, 56, 3, 2, 22, 12, 222,2222, 898989, 4.9]
# lst2.sort()    # Ascending order
# print(lst2)

# print('Descending order: ' )
# lst2.sort(reverse = True)
# print(lst2)
# Out:
# [10, 90, 9, 1, 0, 99, 8, 78, 76, 56, 3, 2, 22, 12, 222, 2222, 898989, 4.9]
# Descending order:
# [898989, 2222, 222, 99, 90, 78, 76, 56, 22, 12, 10, 9, 8, 4.9, 3, 2, 1, 0]

# %%
#Write a Python program to get a sorted list in increasing order of last element in each tuple in a given list using loop.
#Input:- [(5,4),(9,1),(2,3),(5,9),(7,6),(5,5)]
#output:- [(9,1),(2,3),(5,4),(5,5),(7,6),(5,9)]

lst = [(5,4),(9,1),(2,3),(5,9),(7,6),(5,5)]
lst.sort(key = lambda tpl:tpl[-1])
print(lst)
# Out:
# [(9, 1), (2, 3), (5, 4), (5, 5), (7, 6), (5, 9)]

# %%
lst = ['python', 'abc', 'math', 'Polymorph']
lst.sort()
print(lst)
# Out:
# ['Polymorph', 'abc', 'math', 'python']

# %%
a = None

# %%
#Complete the below code str1 = 'This is Python class' 
#write the code to replace 'Python' with 'Java' and you should get below error. 
#TypeError: 'str' object does not support item assignment.

str1 = 'This is Python class' 

str1[8] = 'Java'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-07fd077a6632> in <module>
#       5 str1 = 'This is Python class'
#       6
# ----> 7 str1[8] = 'Java'
#
# TypeError: 'str' object does not support item assignment

# %%
# print(dict(zip(emp_key, emp_val)))
# print(dict(zip(emp_key, emp_val)))
